# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets, preprocessing
from sklearn.linear_model import LinearRegression

# %%
def standard(X):
    return (X-X.mean())/X.std()
    
def min_max(X):
    return (X-X.min())/(X.max()-X.min())
    
def max_abs(X):
    return X/((X.abs()).max())

def robust(X):
    return (X-X.median()) / (np.percentile(X,75) - np.percentile(X,25))

# %%
np.random.seed(2019)
df = pd.DataFrame({
    'x1' : np.random.chisquare(8,10000),
    'x2' : np.random.normal(5,3,10000),
    'x3' : np.random.normal(-5, 5, 10000)
})

# %%
_, (ax1, ax2) = plt.subplots(ncols = 2, figsize=(9, 5))
ax1.set_title('Before')
sns.kdeplot(df['x1'], ax=ax1)
sns.kdeplot(df['x2'], ax=ax1)
sns.kdeplot(df['x3'], ax=ax1)

ax2.set_title('After Srandard')
sns.kdeplot(standard(df['x1']), ax=ax2)
sns.kdeplot(standard(df['x2']), ax=ax2)
sns.kdeplot(standard(df['x3']), ax=ax2)

'''
scaled = preprocessing.StandardScaler().fit_transform(df)
scaled = pd.DataFrame(scaled, columns = ['x1', 'x2', 'x3'])
ax3.set_title('Scaled')
sns.kdeplot(scaled['x1'], ax=ax3)
sns.kdeplot(scaled['x2'], ax=ax3)
sns.kdeplot(scaled['x3'], ax=ax3)
'''
# Out:
# "\nscaled = preprocessing.StandardScaler().fit_transform(df)\nscaled = pd.DataFrame(scaled, columns = ['x1', 'x2', 'x3'])\nax3.set_title('Scaled')\nsns.kdeplot(scaled['x1'], ax=ax3)\nsns.kdeplot(scaled['x2'], ax=ax3)\nsns.kdeplot(scaled['x3'], ax=ax3)\n"

# %%
_, (ax1, ax2) = plt.subplots(ncols = 2, figsize=(9, 5))
ax1.set_title('Before')
sns.kdeplot(df['x1'], ax=ax1)
sns.kdeplot(df['x2'], ax=ax1)
sns.kdeplot(df['x3'], ax=ax1)

ax2.set_title('After Min_Max')
sns.kdeplot(min_max(df['x1']), ax=ax2)
sns.kdeplot(min_max(df['x2']), ax=ax2)
sns.kdeplot(min_max(df['x3']), ax=ax2)

# %%
_, (ax1, ax2) = plt.subplots(ncols = 2, figsize=(9, 5))
ax1.set_title('Before')
sns.kdeplot(df['x1'], ax=ax1)
sns.kdeplot(df['x2'], ax=ax1)
sns.kdeplot(df['x3'], ax=ax1)

ax2.set_title('After Max_Abs')
sns.kdeplot(max_abs(df['x1']), ax=ax2)
sns.kdeplot(max_abs(df['x2']), ax=ax2)
sns.kdeplot(max_abs(df['x3']), ax=ax2)

# %%
_, (ax1, ax2) = plt.subplots(ncols = 2, figsize=(9, 5))
ax1.set_title('Before')
sns.kdeplot(df['x1'], ax=ax1)
sns.kdeplot(df['x2'], ax=ax1)
sns.kdeplot(df['x3'], ax=ax1)

ax2.set_title('After Robust')
sns.kdeplot(robust(df['x1']), ax=ax2)
sns.kdeplot(robust(df['x2']), ax=ax2)
sns.kdeplot(robust(df['x3']), ax=ax2)
